# %% [markdown]
# <h1><center>Diplomado de Ciencias de Datos - Trabajo Final - Octubre 2021</center></h1>
# <h2><center>Caso Práctico: Sistema Provincial de Expedientes (SIE)</center></h2>
# <h3><center>5° Parte</center></h3>
# <h4><center>Ing. Romina C. Scarazzini</center></h4>

# %% [markdown]
# ___
# # Contenido
# - Limpieza de Datos con Power BI: Para ver el detalle de lo realizado en este paso, ver el documento: "Limpieza de Datos con Power BI.pdf"
# - Exploración  y análisis de los datos
# - Análisis de las características de Series Temporales (EDA)
# - **Aplicación de modelos de Machine Learning, enfocados a Series Temporales**
#   - **Paquetes de StatModels**
#     - **SMA: Promedio móvil simple (Simple Moving Average)**
#     - **EWMA: Promedio móvil ponderado exponencialmente (Exponentially Weighted Moving Average)**
#     - **Método de Suavizado Simple**
#     - **Método de Suavizado Doble**
#     - **Método de Suavizado Triple**
#     - **Método de Suavizado Optimizado con Wandb**
# - **Predicciones 2021**

# %% [markdown]
# ___
# # Importación de Paquetes

# %%
# Instalación de paquetes para tratamiento de datos
# ==============================================================================
import numpy as np
import pandas as pd

# Instalación de paquetes para gráficos
# ==============================================================================
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

#Declaración del estilo
#===================================
plt.style.use("bmh")

#Configuración del tamaño de las visualizaciones para que se muestren bien en Jupyter
#==============================================
plt.rcParams["figure.figsize"] = 16, 5

# Configuración warnings
# ==============================================================================
import warnings
warnings.filterwarnings('ignore')

# Para grilla de hiperparámetros del paquete Wandb
#======================================================
from sklearn.model_selection import ParameterGrid

# Wandb (para optimización automática de hiperparámetros)
#====================================
import wandb

#from tqdm.notebook import tqdm

# %% [markdown]
# ### Paquetes para la Evaluación de Error de los Modelos

# %%
# Error Porcentual Absoluto Medio (MAPE)
# Este es uno de lo más usados para Series de Tiempo
#==========================================================
from sklearn.metrics import mean_absolute_percentage_error

# Error absoluto medio: Mean Squared Error (MAE)
#==========================================================
from sklearn.metrics import mean_absolute_error


#Error cuadrático medio: Mean Squared Error (MSE)
#===================================================
from sklearn.metrics import mean_squared_error

#Error logarítmico cuadrático medio
#===================================================
from sklearn.metrics import mean_squared_log_error

# %% [markdown]
# ## Importación de Statsmodels
# Statsmodels es un módulo de Python que proporciona clases y funciones para la estimación de muchos modelos estadísticos diferentes, así como para realizar pruebas estadísticas y exploración de datos estadísticos.

# %%
# Suavizado Exponencial Simple
from statsmodels.tsa.holtwinters import SimpleExpSmoothing

# Suavizado Exponencial Doble y Triple
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %% [markdown]
# ___
# # Recupero los dataset trabajados en la 1° Parte del trabajo

# %%
# Defino como índice la 1° columna y diciendo que es una fecha
#======================================================================
df_total = pd.read_csv("df_total.csv", sep=';', index_col=0, parse_dates=True)
df_train = pd.read_csv("df_train.csv", sep=';', index_col=0, parse_dates=True)
df_test = pd.read_csv("df_test.csv", sep=';', index_col=0, parse_dates=True)
df_total.head()
# Out:
#                  Cant_Expte
# Fecha_Ini_Expte
# 2011-01-03           1144.0
# 2011-01-04           1217.0
# 2011-01-05           1326.0
# 2011-01-06           1377.0
# 2011-01-07           1388.0

# %%
df_train.tail()
# Out:
#                  Cant_Expte
# Fecha_Ini_Expte
# 2018-12-25           1197.0
# 2018-12-26           1197.0
# 2018-12-27           1150.0
# 2018-12-28           1574.0
# 2018-12-31              1.0

# %%
df_test.head()
# Out:
#                  Cant_Expte
# Fecha_Ini_Expte
# 2019-01-01              1.0
# 2019-01-02            974.0
# 2019-01-03           1309.0
# 2019-01-04           1093.0
# 2019-01-07           1165.0

# %%
# Recupero los expedientes agrupados por semana (si uso este dataset, no uso el que sigue)
#=============================================================================
df_Week = pd.read_csv("df_Week.csv", sep=';', index_col=0, parse_dates=True)
#df_Week = df_Week.rename(columns={'index': 'Cant_Expte'})

# %%
# Recupero los expedientes segun su tendendia (si uso este dataset, no uso el anterior)
#=============================================================================
df_Week = pd.read_csv("df_Tend.csv", sep=';', index_col=0, parse_dates=True)

# %%
# División de los datos agrupados semanales: 80/20
#=================================================
size = int(len(df_Week)*0.8)
df_train_w = df_Week.iloc[:size]
df_test_w = df_Week.iloc[size:]

# %%
df_train_w.tail()
# Out:
#                   Cant_Expte
# Fecha_Ini_Expte
# 2018-11-25       5815.582389
# 2018-12-02       5761.057464
# 2018-12-09       5706.566725
# 2018-12-16       5652.649175
# 2018-12-23       5599.847837

# %%
df_test_w.head()
# Out:
#                   Cant_Expte
# Fecha_Ini_Expte
# 2018-12-30       5549.988451
# 2019-01-06       5505.591854
# 2019-01-13       5468.162016
# 2019-01-20       5437.878785
# 2019-01-27       5415.028158

# %% [markdown]
# ___
# # Métodos de Suavizado
# ## SMA: Promedio móvil simple (Simple Moving Average)

# %% [markdown]
# $SMA=\frac{x_1+x_2+...+x_n}{n} $

# %% [markdown]
# donde $x_i$ son los valores de la variable, por tanto $SMA$ es un promedio aritmético de $n$ períodos atrás.

# %%
#Window es el espacio temporal que estoy considerando para calcular las estimaciones por el método promedio móvil simple.
#====================================================================================
df_train_w['SMA'] = df_train_w['Cant_Expte'].rolling(window=52).mean()

# %%
df_train_w.head(15)
# Out:
#    Fecha_Ini_Expte  Cant_Expte  SMA         EWMA
# 0       2011-01-09        6453  NaN  6453.000000
# 1       2011-01-16        5768  NaN  6427.150943
# 2       2011-01-23        4948  NaN  6371.333927
# 3       2011-01-30        4917  NaN  6316.453401
# 4       2011-02-06        6222  NaN  6312.889122
# 5       2011-02-13        7399  NaN  6353.874438
# 6       2011-02-20        7383  NaN  6392.709365
# 7       2011-02-27        7710  NaN  6442.418445
# 8       2011-03-06        8281  NaN  6511.798881
# 9       2011-03-13        4824  NaN  6448.108358
# 10      2011-03-20        9021  NaN  6545.198608
# 11      2011-03-27        4828  NaN  6480.398661
# 12      2011-04-03        8299  NaN  6549.025126
# 13      2011-04-10        9054  NaN  6643.552480
# 14      2011-04-17        8923  NaN  6729.569368

# %% [markdown]
# ### Gráfico: Serie de Tiempo y Promedio Móvil Simple (SMA)

# %%
fig, ax=plt.subplots()
df_train_w['Cant_Expte'].plot(ax=ax, label='Serie de Tiempo', color="darkorange", alpha=0.8)
df_train_w['SMA'].plot(ax=ax, label='SMA',color="royalblue", alpha=0.8)
plt.title("Serie de Tiempo y Promedio Móvil Simple (SMA)", fontsize=22)
plt.xlabel("Años")
ax.legend();

# %% [markdown]
# #### Desventajas de este método
# - Le da el mismo peso a todas las observaciones de los datos, sin tener en cuenta la antigüedad de los mismos
# - Hay valores nulos. En este caso, no se puede calcular hasta tener 260 días (1 año laboral)

# %% [markdown]
# ## EWMA: Promedio Móvil Ponderado Exponencialmente (Exponentially Weighted Moving Average)

# %% [markdown]
# EWMA nos permitirá reducir el efecto de retraso de SMA y pondrá más peso en los valores que ocurrieron más recientemente. La cantidad de peso aplicada a los valores más recientes dependerá de los parámetros utilizados en EWMA, la fórmula con la que se calculan las estimaciones es:
#
# ### $y_t =   \frac{\sum\limits_{i=0}^t w_i x_{t-i}}{\sum\limits_{i=0}^t w_i}$

# %% [markdown]
# Donde $x_t$ son los valores de la variable, $w_i$ son los pesos (desde $i=0$ hasta $t$), y la $y_t$ es la estimación resultante.
#
# La pregunta es ¿cómo se deben definir los pesos $w_i$?
#
# Esto depende del argumento <tt>adjust</tt> dentro de la función <tt>.ewm()</tt>.
#
# Cuando <tt>adjust=True</tt> (por defecto), los pesos se calculan con esta ecuación: $w_i = (1 - \alpha)^i$
#
# Lo cual resulta en estas estimaciones:
#
# ### $y_t = \frac{x_t + (1 - \alpha)x_{t-1} + (1 - \alpha)^2 x_{t-2} + ...
# + (1 - \alpha)^t x_{0}}{1 + (1 - \alpha) + (1 - \alpha)^2 + ...
# + (1 - \alpha)^t}$

# %% [markdown]
# Cuando <tt>adjust=False</tt> las estimaciones se calculan como:
#
# ### $\begin{split}y_0 &= x_0 \\
# y_t &= (1 - \alpha) y_{t-1} + \alpha x_t,\end{split}$
#
# que es equivalente a usar estos pesos:
#
#  \begin{split}w_i = \begin{cases}
#     \alpha (1 - \alpha)^i & \text{si } i < t \\
#     (1 - \alpha)^i        & \text{si } i = t.
# \end{cases}\end{split}

# %% [markdown]
# El parámetro de suavizado $\alpha$ tiene que ser un valor $0<\alpha≤1$.
# Es posible pasar directamente el valor del parámetro, pero una mejor práctica es pensar en él como una función de estos tres posibles factores:
# 1. Span (duración)
# 2. Center of mass (centro de masa)
# 3. Half-life (vida media)

# %% [markdown]
# \begin{split}\alpha =
#  \begin{cases}
#      \frac{2}{s + 1},               & \text{para una duracion (span)}\ s \geq 1\\
#      \frac{1}{1 + c},               & \text{para un centro de masa}\ c \geq 0\\
#      1 - \exp^{\frac{\log 0.5}{h}}, & \text{para un parametro half-life}\ h > 0
#  \end{cases}\end{split}

# %% [markdown]
# * <strong>Span</strong> corresponde a lo que comúnmente se llama un "promedio móvil de N-períodos"
# * <strong>Center of mass</strong> tiene una interpretación más física y se puede pensar en términos de la duración: $c=(s−1)/2$
# * <strong>Half-life</strong> es el período de tiempo para que el peso exponencial se reduzca a la mitad.
# * <strong>Alpha</strong> es el parámetro de suavizado directamente.
#
# Tenemos que pasar alguno de esos argumentos a la función. En nuestro ejemplo vamos a usar <tt>span=260</tt>.

# %%
df_train_w['EWMA'] = df_train_w['Cant_Expte'].ewm(span=52,adjust=False).mean()

# %%
df_train_w.head(15)
# Out:
#                  Cant_Expte  SMA         EWMA
# Fecha_Ini_Expte
# 2011-01-09             6453  NaN  6453.000000
# 2011-01-16             5768  NaN  6427.150943
# 2011-01-23             4948  NaN  6371.333927
# 2011-01-30             4917  NaN  6316.453401
# 2011-02-06             6222  NaN  6312.889122
# 2011-02-13             7399  NaN  6353.874438
# 2011-02-20             7383  NaN  6392.709365
# 2011-02-27             7710  NaN  6442.418445
# 2011-03-06             8281  NaN  6511.798881
# 2011-03-13             4824  NaN  6448.108358
# 2011-03-20             9021  NaN  6545.198608
# 2011-03-27             4828  NaN  6480.398661
# 2011-04-03             8299  NaN  6549.025126
# 2011-04-10             9054  NaN  6643.552480
# 2011-04-17             8923  NaN  6729.569368

# %% [markdown]
# ### Gráfico: Serie de Tiempo y Promedio Móvil Ponderado Exponencialmente (EWMA)

# %%
fig, ax=plt.subplots()
df_train_w['Cant_Expte'].plot(ax=ax, label='Serie de Tiempo', color="darkorange", alpha=0.8)
df_train_w['EWMA'].plot(ax=ax, label='EWMA',color="royalblue", alpha=0.8)
plt.title("Serie de Tiempo y Promedio Móvil Ponderado Exponencialmente (EWMA)", fontsize=22)
plt.xlabel("Años")
ax.legend();

# %% [markdown]
# #### Colclusiones
# - Este tipo de tendencia de estacionalidad es mas acorde porque se ha especificado que los puntos más cercanos al presente sean más pesados que los puntos más antiguos
# - Además aquí no se tiene el problema de falta de valores al principio

# %% [markdown]
# ### Gráfico: Comparación de la Serie Temporal, SMA y EWMA

# %%
fig, ax=plt.subplots()
df_train_w['Cant_Expte'].plot(ax=ax, label='Serie de Tiempo', color="darkorange", alpha=0.8)
df_train_w['SMA'].plot(ax=ax, label='SMA',color="royalblue", alpha=0.8)
df_train_w['EWMA'].plot(ax=ax, label='EWMA',color="firebrick", alpha=0.8)
plt.title("Comparación de la Serie Temporal, SMA y EWMA", fontsize=22)
plt.xlabel("Años")
ax.legend();

# %% [markdown]
# #### Concluisiones
# Tanto SMA como EWMA hacen un mal trabajo de pronóstico en nuestra serie de tiempo

# %% [markdown]
# ___
# # Métodos Suavizado Exponencial
# Este método tiene en cuenta factores como la tendencia y la estacionalidad.
# En el <strong> Suavizado exponencial doble </strong> (también conocido como Método de Holt) presentamos un nuevo factor de suavizado $\beta$ (beta) que aborda la tendencia:
#
# \begin{split}l_t &= (1 - \alpha) l_{t-1} + \alpha x_t, & \text{    nivel}\\
# b_t &= (1-\beta)b_{t-1} + \beta(l_t-l_{t-1}) & \text{    tendencia}\\
# y_t &= l_t + b_t & \text{    modelo estimado}\\
# \hat y_{t+h} &= l_t + hb_t & \text{    modelo de pronósticos (} h = \text{# periodos en el futuro)}\end{split}
#
#
# Con <strong> Suavizado exponencial triple </strong> (también conocido como Método Holt-Winters) presentamos un factor de suavizado $\gamma$ (gamma) que aborda la estacionalidad:
#
# \begin{split}l_t &= (1 - \alpha) l_{t-1} + \alpha x_t, & \text{    nivel}\\
# b_t &= (1-\beta)b_{t-1} + \beta(l_t-l_{t-1}) & \text{    tendencia}\\
# c_t &= (1-\gamma)c_{t-L} + \gamma(x_t-l_{t-1}-b_{t-1}) & \text{    estacionalidad}\\
# y_t &= (l_t + b_t) c_t & \text{    modelo estimado}\\
# \hat y_{t+m} &= (l_t + mb_t)c_{t-L+1+(m-1)modL} & \text{    modelo de pronosticos (} m = \text{# periodos en el futuro)}\end{split}
#
# Aquí $ L $ representa el número de divisiones por ciclo. En nuestro caso, mirando los datos diarios que muestran un patrón repetitivo cada año laboral, usaríamos $ L = 260 $.
#
# En general, los valores más altos para $ \alpha $, $ \beta $ y $ \gamma $ (valores más cercanos a 1), ponen más énfasis en los datos recientes.
#
# <div class="alert alert-info"><h3>Funciones:</h3>
# <tt><strong><a href='https://www.statsmodels.org/stable/generated/statsmodels.tsa.holtwinters.SimpleExpSmoothing.html'>statsmodels.tsa.holtwinters.SimpleExpSmoothing</a></strong><font color=black></font>&nbsp;&nbsp;&nbsp;&nbsp;
# Simple Exponential Smoothing<br>
# <strong><a href='https://www.statsmodels.org/stable/generated/statsmodels.tsa.holtwinters.ExponentialSmoothing.html'>statsmodels.tsa.holtwinters.ExponentialSmoothing</a></strong><font color=black></font>&nbsp;&nbsp;
#     Holt-Winters Exponential Smoothing</tt>

# %%
#Configuro la frecuencia de la serie con 'b', lo cual indica Business days
#==============================================================================
df_train_w.index.freq = 'w'
df_train_w.index
# Out:
# DatetimeIndex(['2011-01-09', '2011-01-16', '2011-01-23', '2011-01-30',
#                '2011-02-06', '2011-02-13', '2011-02-20', '2011-02-27',
#                '2011-03-06', '2011-03-13',
#                ...
#                '2018-10-21', '2018-10-28', '2018-11-04', '2018-11-11',
#                '2018-11-18', '2018-11-25', '2018-12-02', '2018-12-09',
#                '2018-12-16', '2018-12-23'],
#               dtype='datetime64[ns]', name='Fecha_Ini_Expte', length=416, freq='W-SUN')

# %%
df_train_w.head()
# Out:
#                  Cant_Expte  SMA         EWMA
# Fecha_Ini_Expte
# 2011-01-09             6453  NaN  6453.000000
# 2011-01-16             5768  NaN  6427.150943
# 2011-01-23             4948  NaN  6371.333927
# 2011-01-30             4917  NaN  6316.453401
# 2011-02-06             6222  NaN  6312.889122

# %% [markdown]
# ___
# ## SuavizadoExponencial simple (SES)
# El suavizado exponencial simple (SES) es lo mismo que promedio móvil ponderado exponencialmente (EWMA). Esto es así si el parámetro 'optimized' es igual a "False"

# %%
# Suavizado exponencial simple (SES) 
#====================================================================================================================================
span = 51
alpha = 2/(span+1)
df_train_w['SES'] = SimpleExpSmoothing(df_train_w['Cant_Expte']).fit(smoothing_level=alpha,optimized=True).fittedvalues.shift(-1)
df_train_w.head()
# Out:
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
#                   Cant_Expte  SMA         EWMA          SES
# Fecha_Ini_Expte
# 2011-01-09       5960.575560  NaN  5960.575560  7128.027269
# 2011-01-16       6091.158324  NaN  5965.503212  7088.147694
# 2011-01-23       6222.048853  NaN  5975.184179  7054.836200
# 2011-01-30       6353.352938  NaN  5989.454699  7027.856075
# 2011-02-06       6484.380091  NaN  6008.131128  7006.953152

# %% [markdown]
# <div class = "alert alert-danger"> <strong> NOTA: </strong> por alguna razón, cuando <tt> optimized = False </tt> se pasa a <tt>.fit()</tt>, la función statsmodels <tt> SimpleExpSmoothing </tt> desplaza los valores ajustados una fila hacia abajo. Arreglamos esto agregando <tt>.shift(-1)</tt> después de <tt>.fittedvalues</tt> </div>

# %% [markdown]
# ### Gráfico: SuavizadoExponencial simple (SES)

# %%
fig, ax=plt.subplots()
df_train_w['Cant_Expte'].plot(ax=ax, label='Serie de Tiempo', color="darkorange", alpha=0.8)
df_train_w['SMA'].plot(ax=ax, label='SMA',color="royalblue", alpha=1)
df_train_w['EWMA'].plot(ax=ax, label='EWMA',color="forestgreen", alpha=1)
df_train_w['SES'].plot(ax=ax, label='SES',color="firebrick", alpha=0.8)
plt.title("Comparación Suavizado SMA EWNA y SES", fontsize=22)
plt.xlabel("Años")
ax.legend();

# %% [markdown]
# ### Conclusiones
# - El método de suavizado exponencial simple (SES) de Statmodel es similar a EWMA
# - Y es igual a EWMA si el parámetro 'optimized' es igual a "False"

# %% [markdown]
# ___
# ## Suavizado Exponencial Doble
# - Cuando el suavizado exponencial simple emplea solo un factor de suavizado $ \alpha $ (alpha), el suavizado exponencial doble agrega un segundo factor de suavizado $ \beta $ (beta) que aborda las tendencias en los datos
# - Al igual que el factor alpha, los valores para el factor beta están entre cero y uno ($ 0 <\beta≤1 $). El beneficio aquí es que el modelo puede anticipar futuros aumentos o disminuciones donde el modelo de un solo factor solo tendría en cuenta los valores más recientes
# - También podemos abordar diferentes tipos de cambio (crecimiento / decrecimiento) en la tendencia. Si una serie temporal muestra una tendencia inclinada en línea recta, se usaría un ajuste <strong> aditivo </strong>. Si la serie temporal muestra una tendencia exponencial (curva), se usaría un ajuste <strong> multiplicativo </strong>
# >
# Primero vamos a usar un ajuste estacional **aditivo**.

# %% [markdown]
# ### Suavizado Exponencial Doble con tendencia aditiva

# %%
df_train_w['DESadd'] = ExponentialSmoothing(df_train_w['Cant_Expte'], trend = 'add').fit().fittedvalues.shift(-1)
df_train_w.head()
# Out:
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
#                   Cant_Expte  SMA         EWMA          SES       DESadd
# Fecha_Ini_Expte
# 2011-01-09       5960.575560  NaN  5960.575560  7128.027269  6096.874991
# 2011-01-16       6091.158324  NaN  5965.503212  7088.147694  6221.741088
# 2011-01-23       6222.048853  NaN  5975.184179  7054.836200  6352.939382
# 2011-01-30       6353.352938  NaN  5989.454699  7027.856075  6484.657024
# 2011-02-06       6484.380091  NaN  6008.131128  7006.953152  6615.407244

# %% [markdown]
# #### Gráfico: Serie Temporal, EWMA (Promedio Móvil Ponderado exponencialmente) y Suavizado Exponencial Doble con tendencia aditiva

# %%
fig, ax=plt.subplots()
df_train_w['Cant_Expte'].plot(ax=ax, label='Serie de Tiempo', color="darkorange", alpha=0.8)
df_train_w['SES'].plot(ax=ax, label='SES',color="royalblue", alpha=0.8)
df_train_w['DESadd'].plot(ax=ax, label='SED-ADD',color="firebrick", alpha=0.8)
plt.title("Serie Temporal, SES y SED con Tendencia Aditiva", fontsize=22)
plt.xlabel("Años")
ax.legend();
# iloc[:1000].

# %% [markdown]
# #### Conclusiones
# - Aquí podemos ver que con el suavizado exponencial doble con tendencia aditiva obtenemos una mejor representación de los datos

# %% [markdown]
# ### Suavizado Exponencial Doble con tendencia multiplicativa

# %%
df_train_w['DESmul'] = ExponentialSmoothing(df_train_w['Cant_Expte'], trend='mul').fit().fittedvalues.shift(-1)
df_train_w.head()
# Out:
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
#                   Cant_Expte  SMA         EWMA          SES       DESadd  \
# Fecha_Ini_Expte
# 2011-01-09       5960.575560  NaN  5960.575560  7128.027269  6096.874991
# 2011-01-16       6091.158324  NaN  5965.503212  7088.147694  6221.741088
# 2011-01-23       6222.048853  NaN  5975.184179  7054.836200  6352.939382
# 2011-01-30       6353.352938  NaN  5989.454699  7027.856075  6484.657024
# 2011-02-06       6484.380091  NaN  6008.131128  7006.953152  6615.407244
#
#                       DESmul
# Fecha_Ini_Expte
# 2011-01-09       5971.666374
# 2011-01-16       6210.351568
# 2011-01-23       6358.301446
# 2011-01-30       6488.205433
# 2011-02-06       6618.293641

# %% [markdown]
# #### Gráfico: Serie Temporal, SED con tendencia aditiva y SED con tendencia multiplicativa

# %%
fig, ax=plt.subplots()
df_train_w['Cant_Expte'].plot(ax=ax, label='Serie de Tiempo', color="darkorange", alpha=0.8)
df_train_w['DESadd'].plot(ax=ax, label='SED-ADD',color="royalblue", alpha=0.8)
df_train_w['DESmul'].plot(ax=ax, label='SED-MUL',color="firebrick", alpha=0.8)
plt.title("Serie Temporal, SED Aditivo y SED Multiplicativo", fontsize=22)
plt.xlabel("Años")
ax.legend();
#iloc[:200].

# %% [markdown]
# #### Conclusiones
# - Vemos que en la primer parte de la serie, el suavizado exponencial doble aditivo ajusta mejor los datos que el suavizado exponencial doble multiplicativo
# - Luego ambos ajustan los datos de forma similar

# %% [markdown]
# ___
# ## Predicciones: Método de Suavizado Doble (SED)
# Se usará una ventana temporal del futuro de 522 días laborales (2 años)

# %%
model_DESadd = ExponentialSmoothing(df_train_w['Cant_Expte'], trend = 'add').fit()
model_DESmul = ExponentialSmoothing(df_train_w['Cant_Expte'], trend= 'mul').fit()
# Out:
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'

# %%
# Hago los pronósticos considerando un Forecast de ambos modelos con una ventana temporal de 730 días (2 años)
#===============================================================================
forecast_DESadd = model_DESadd.forecast(105)
forecast_DESmul = model_DESmul.forecast(105)

# %% [markdown]
# ### Gráfico: Datos de trainning, test y las predicciones con SED-ADD y SED-MUL

# %%
fig, ax=plt.subplots()
df_train_w['Cant_Expte'].plot(ax=ax, label='Training', color="darkorange", alpha=0.8)
df_test_w['Cant_Expte'].plot(ax=ax, label='Test',color="firebrick", alpha=0.8)
forecast_DESadd.plot(ax=ax, label='Predic SED-ADD',color="royalblue", alpha=0.8)
forecast_DESmul.plot(ax=ax,label='Predic SED-MUL',color="forestgreen", alpha=0.6)
plt.title("Datos de Trainning, Test y Predicciones con SED-ADD y SET-MUL", fontsize=22)
plt.xlabel("Años")
ax.legend();
#.iloc[2000:]

# %% [markdown]
# #### Colcusiones
# - Vemos en el gráfcio que los métodos de SED no son buenos para realizar prediccines en nuestra serie de tiempo

# %% [markdown]
# ___
# ## Evaluación del Error del Modelo SED

# %% [markdown]
# ### MAE (Error Absoluto Medio)

# %%
labels = ['SED_ADD','SED_MUL']
predic = [forecast_DESadd, forecast_DESmul]  # Estas son variables, no son strings

for i in range(2):
    error = mean_absolute_error(df_test_w['Cant_Expte'], predic[i])
    print(f'MAE {labels[i]}: {error:11.10}')
# Out:
# MAE SED_ADD: 1826.035857
# MAE SED_MUL: 1083.610428

# %% [markdown]
# ### MAPE (Error Porcentual Absoluto Medio)

# %%
labels = ['SED_ADD','SED_MUL']
predic = [forecast_DESadd, forecast_DESmul]  # Estas son variables, no son strings

for i in range(2):
    error = mean_absolute_percentage_error(df_test_w['Cant_Expte'], predic[i])
    print(f'MAPE {labels[i]}: {error:11.10}')
# Out:
# MAPE SED_ADD: 0.4191481681
# MAPE SED_MUL: 0.2320162425

# %% [markdown]
# ### MSE (Error Cuadrático Medio)

# %%
labels = ['SED_ADD','SED_MUL']
predic = [forecast_DESadd, forecast_DESmul]  # Estas son variables, no son strings

for i in range(2):
    error = mean_squared_error(df_test_w['Cant_Expte'], predic[i])
    print(f'MSE {labels[i]}: {error:11.10}')
# Out:
# MSE SED_ADD: 4587517.583
# MSE SED_MUL: 1658478.092

# %%
RMSE_SED_ADD = error**0.5
RMSE_SED_ADD
# Out:
# 1287.81912253093

# %% [markdown]
# ### Conclusiones
# - Vemos que para el modelo SED, el mejor MAPE lo tiene el método multiplicativo
# - Igualmente, viendo la gráfica concluimos que éste no es un buen método para predecir nuestra serie de tiempo

# %% [markdown]
# ___
# ## Suavizado Exponencial Triple (SET)
# - Suavizado exponencial triple o Holt-Winters, añade soporte para la tendencia y la estacionalidad

# %% [markdown]
# ### Suavizado Exponencial Triple con tendencia aditiva

# %%
df_train_w['TESadd'] = ExponentialSmoothing(df_train_w['Cant_Expte'],trend='add',seasonal='add',seasonal_periods=51).fit().fittedvalues
df_train_w.head()
# Out:
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
#                   Cant_Expte  SMA         EWMA          SES       DESadd  \
# Fecha_Ini_Expte
# 2011-01-09       5960.575560  NaN  5960.575560  7128.027269  6096.874991
# 2011-01-16       6091.158324  NaN  5965.503212  7088.147694  6221.741088
# 2011-01-23       6222.048853  NaN  5975.184179  7054.836200  6352.939382
# 2011-01-30       6353.352938  NaN  5989.454699  7027.856075  6484.657024
# 2011-02-06       6484.380091  NaN  6008.131128  7006.953152  6615.407244
#
#                       DESmul       TESadd
# Fecha_Ini_Expte
# 2011-01-09       5971.666374  6131.711889
# 2011-01-16       6210.351568  5768.225169
# 2011-01-23       6358.301446  6025.370287
# 2011-01-30       6488.205433  6266.524670
# 2011-02-06       6618.293641  6461.241677

# %% [markdown]
# #### Gráfico: Serie Temporal y SET con tendencia aditiva

# %%
fig, ax=plt.subplots()
df_train_w['Cant_Expte'].plot(ax=ax, label='Serie de Tiempo', color="darkorange", alpha=0.8)
df_train_w['TESadd'].plot(ax=ax, label='SET-ADD',color="royalblue", alpha=0.6)
plt.title("Serie Temporal, SET con Tendencia Aditiva", fontsize=22)
plt.xlabel("Años")
ax.legend();

# %% [markdown]
# ### Conclusiones
# - En la primer parte de gráfico los datos de la serie son muy similares a los de SET con tendencia aditiva
# - Luego vemos que el SET-ADD se ajusta bastante bien a la serie, solo que tiene más picos que los métodos con SED

# %% [markdown]
# ### Suavizado Exponencial Triple con tendencia multiplicativa

# %%
df_train_w['TESmul'] = ExponentialSmoothing(df_train_w['Cant_Expte'],trend='mul',seasonal='mul',seasonal_periods=51).fit().fittedvalues
df_train_w.head()
# Out:
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
#                   Cant_Expte  SMA         EWMA          SES       DESadd  \
# Fecha_Ini_Expte
# 2011-01-09       5960.575560  NaN  5960.575560  7128.027269  6096.874991
# 2011-01-16       6091.158324  NaN  5965.503212  7088.147694  6221.741088
# 2011-01-23       6222.048853  NaN  5975.184179  7054.836200  6352.939382
# 2011-01-30       6353.352938  NaN  5989.454699  7027.856075  6484.657024
# 2011-02-06       6484.380091  NaN  6008.131128  7006.953152  6615.407244
#
#                       DESmul       TESadd       TESmul
# Fecha_Ini_Expte
# 2011-01-09       5971.666374  6131.711889  6800.450029
# 2011-01-16       6210.351568  5768.225169  5839.886389
# 2011-01-23       6358.301446  6025.370287  5926.391542
# 2011-01-30       6488.205433  6266.524670  6186.108720
# 2011-02-06       6618.293641  6461.241677  6381.908162

# %% [markdown]
# #### Gráfico: Serie Temporal, SET con tendencia aditiva y SET con tendencia multiplicativa

# %%
fig, ax=plt.subplots()
df_train_w['Cant_Expte'].plot(ax=ax, label='Serie de Tiempo', color="darkorange", alpha=0.8)
df_train_w['TESadd'].plot(ax=ax, label='SET-ADD',color="royalblue", alpha=0.8)
df_train_w['TESmul'].plot(ax=ax, label='SET-MUL',color="firebrick", alpha=0.6)
plt.title("Serie Temporal, SET con Tendencia Aditiva y Multiplicativa", fontsize=22)
plt.xlabel("Años")
ax.legend();
#iloc[400:1000]

# %% [markdown]
# #### Conclusiones
# - Vemos que en la primer parte de la serie, SET con tendencia aditiva, es casi igual a la serie de tiempo
# - Luego vemos que SET-ADD ajusta mejor los datos de la serie que SET-MUL

# %% [markdown]
# ___
# ## Predicciones: Métodos de Suavizado Exponencial Triple (SET)
# Ventana temporal del futuro de 522 días laborales (2 años)

# %%
model_TESadd = ExponentialSmoothing(df_train_w['Cant_Expte'],trend='add',seasonal='add',seasonal_periods=51).fit()
model_TESmul = ExponentialSmoothing(df_train_w['Cant_Expte'],trend='mul',seasonal='mul',seasonal_periods=51).fit()
# Out:
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'

# %%
# Hago los pronósticos considerando un Forecast de ambos modelos con una ventana temporal de 522 días laborales (2 años)
#===============================================================================
forecast_TESadd = model_TESadd.forecast(105)
forecast_TESmul = model_TESmul.forecast(105)

# %% [markdown]
# ### Gráfico: Datos de trainning, test y las predicciones con SET-ADD y SET-MUL

# %%
fig, ax=plt.subplots()
df_train_w['Cant_Expte'].plot(ax=ax, label='Training', color="darkorange", alpha=0.8)
df_test_w['Cant_Expte'].plot(ax=ax, label='Test',color="firebrick", alpha=0.8)
forecast_TESadd.plot(ax=ax, label='Predic SET-ADD',color="royalblue", alpha=0.8)
forecast_TESmul.plot(ax=ax,label='Predic SET-MUL',color="forestgreen", alpha=0.6)
plt.title("Datos de Trainning, Test y Predicciones con SET-ADD y SET-MUL", fontsize=22)
plt.xlabel("Años")
ax.legend();
#.iloc[2000:]

# %% [markdown]
# #### Conclusiones
# - Podemos ver que los datos originales tienen cierta estacionalidad con una leve variación de los ciclos que van disminuyendo en el tiempo
# - La tendencia de nuestra serie es basicamente lineal
# - El modelo de Suavizado Exponencial Triple con tendencia aditiva, realiza hasta el momento, la mejor predicción de los datos de nuestra serie

# %% [markdown]
# ___
# ## Evaluación del Error del Modelo SET

# %% [markdown]
# ### MAE (Error Absoluto Medio)

# %%
labels = ['SET_ADD', 'SET_MUL']
predic = [forecast_TESadd, forecast_TESmul]  # Estas son variables, no son strings

for i in range(2):
    error = mean_absolute_error(df_test_w['Cant_Expte'], predic[i])
    print(f'MAE {labels[i]}: {error:11.10}')
# Out:
# MAE SET_ADD: 6857.177787
# MAE SET_MUL: 1627.025422

# %% [markdown]
# ### MAPE (Error Porcentual Absoluto Medio)

# %%
labels = ['SED_ADD','SED_MUL']
predic = [forecast_TESadd, forecast_TESmul]  # Estas son variables, no son strings

for i in range(2):
    error = mean_absolute_percentage_error(df_test_w['Cant_Expte'], predic[i])
    print(f'MAE {labels[i]}: {error:11.10}')
# Out:
# MAE SED_ADD: 1.658022345
# MAE SED_MUL: 0.3650598802

# %% [markdown]
# ### MSE (Error Cuadrático Medio)

# %%
labels = ['SET_ADD', 'SET_MUL']
predic = [forecast_TESadd, forecast_TESmul]  # Estas son variables, no son strings

for i in range(2):
    error = mean_squared_error(df_test_w['Cant_Expte'], predic[i])
    print(f'MSE {labels[i]}: {error:11.10}')
# Out:
# MSE SET_ADD: 66634390.33
# MSE SET_MUL: 3604924.621

# %% [markdown]
# ### Conclusiones
# - Vemos que para el modelo **Suavizado Exponencial Triple**, el **MAPE más bajo** lo tiene el **método aditivo**
# - También, viendo la gráfica concluimos que el mejor método para predecir nuestra serie es el **Suavizado Exponencial Triple con tendencia aditiva**
#
# #### Ahora vamos a realizar una optimización de los hiperparámetros para buscar el modelo de Suavizado Exponecial Óptimo

# %% [markdown]
# ___
# ## Optimización de Hiperparámetros del modelo "ExponentialSmoothing" con el paquete Wandb

# %%
params = {
    "trend": ["add", "mul", "additive", "multiplicative"],
    "damped_trend": [True, False],
    "seasonal": ["add", "mul", "additive", "multiplicative", None],
    "seasonal_periods": [4, 51],
    "initialization_method": [None, "estimated", "heuristic", "legacy-heuristic"]
}

parameter_grid = ParameterGrid(params)

len(parameter_grid)
# Out:
# 320

# %%
# for index, parameter in tqdm(enumerate(parameter_grid, start=1), total=combinations):
#combinations = 100
datos_train = df_train_w.Cant_Expte
datos_test = df_test_w.Cant_Expte

for parameter in parameter_grid:
    run = wandb.init(project = "Expedientes_Tend", reinit = True)
    run.config.update(parameter)
   # print(parameter)
    
    model_SE = ExponentialSmoothing(datos_train, **parameter).fit()
    
   # results_SE = model_SE.fit()
    Pred_SE = model_SE.forecast(105)
    
    metrics = mean_absolute_percentage_error(datos_test, Pred_SE)
    metrics = {"MAPE": [metrics]}
    run.log(metrics)
    run.finish()
    
 #   if index >= combinations:
 #       break
# Out:
# wandb: Currently logged in as: rominacarmen (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">graceful-serenity-1</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/362vw0pu" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/362vw0pu</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150041-362vw0pu</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# <br/>Waiting for W&B process to finish, PID 13200<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150041-362vw0pu\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150041-362vw0pu\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">graceful-serenity-1</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/362vw0pu" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/362vw0pu</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">absurd-smoke-2</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/owdqkbm4" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/owdqkbm4</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150046-owdqkbm4</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 5984<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150046-owdqkbm4\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150046-owdqkbm4\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">absurd-smoke-2</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/owdqkbm4" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/owdqkbm4</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">proud-bird-3</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/1yr233n1" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/1yr233n1</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150052-1yr233n1</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# <br/>Waiting for W&B process to finish, PID 3416<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150052-1yr233n1\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150052-1yr233n1\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">proud-bird-3</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/1yr233n1" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/1yr233n1</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">denim-meadow-4</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3107r0np" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3107r0np</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150058-3107r0np</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 12956<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150058-3107r0np\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150058-3107r0np\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">denim-meadow-4</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3107r0np" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3107r0np</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">amber-armadillo-5</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/2q2c81ny" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/2q2c81ny</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150104-2q2c81ny</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# <br/>Waiting for W&B process to finish, PID 6712<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150104-2q2c81ny\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150104-2q2c81ny\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">amber-armadillo-5</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/2q2c81ny" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/2q2c81ny</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">sweet-disco-6</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/omlz2koi" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/omlz2koi</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150110-omlz2koi</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 5476<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150110-omlz2koi\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150110-omlz2koi\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">sweet-disco-6</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/omlz2koi" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/omlz2koi</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">graceful-cherry-7</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/1j7drrqt" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/1j7drrqt</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150115-1j7drrqt</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# <br/>Waiting for W&B process to finish, PID 8840<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150115-1j7drrqt\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150115-1j7drrqt\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">graceful-cherry-7</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/1j7drrqt" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/1j7drrqt</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">noble-surf-8</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/1g48wu4i" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/1g48wu4i</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150121-1g48wu4i</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 11432<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150121-1g48wu4i\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150121-1g48wu4i\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">noble-surf-8</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/1g48wu4i" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/1g48wu4i</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">wandering-meadow-9</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/25uzyibf" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/25uzyibf</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150126-25uzyibf</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# <br/>Waiting for W&B process to finish, PID 2948<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150126-25uzyibf\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150126-25uzyibf\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">wandering-meadow-9</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/25uzyibf" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/25uzyibf</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">eager-durian-10</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/2v9hcedr" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/2v9hcedr</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150132-2v9hcedr</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# <br/>Waiting for W&B process to finish, PID 7464<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150132-2v9hcedr\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150132-2v9hcedr\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">eager-durian-10</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/2v9hcedr" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/2v9hcedr</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">generous-violet-11</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/34y9m1ir" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/34y9m1ir</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150138-34y9m1ir</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# <br/>Waiting for W&B process to finish, PID 10244<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150138-34y9m1ir\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150138-34y9m1ir\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">generous-violet-11</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/34y9m1ir" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/34y9m1ir</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">misunderstood-elevator-12</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/1xwno4fn" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/1xwno4fn</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150143-1xwno4fn</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# <br/>Waiting for W&B process to finish, PID 14112<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150143-1xwno4fn\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150143-1xwno4fn\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">misunderstood-elevator-12</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/1xwno4fn" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/1xwno4fn</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">stilted-river-13</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/2ogulp2s" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/2ogulp2s</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150150-2ogulp2s</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# <br/>Waiting for W&B process to finish, PID 2932<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150150-2ogulp2s\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150150-2ogulp2s\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">stilted-river-13</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/2ogulp2s" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/2ogulp2s</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">generous-surf-14</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3c7wkijy" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3c7wkijy</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150155-3c7wkijy</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# <br/>Waiting for W&B process to finish, PID 8864<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150155-3c7wkijy\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150155-3c7wkijy\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">generous-surf-14</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3c7wkijy" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3c7wkijy</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">sage-silence-15</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3cyelksl" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3cyelksl</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150201-3cyelksl</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# <br/>Waiting for W&B process to finish, PID 14148<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150201-3cyelksl\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150201-3cyelksl\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">sage-silence-15</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3cyelksl" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3cyelksl</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">elated-violet-16</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3tmailrp" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3tmailrp</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150208-3tmailrp</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# <br/>Waiting for W&B process to finish, PID 15072<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150208-3tmailrp\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150208-3tmailrp\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">elated-violet-16</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3tmailrp" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3tmailrp</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">scarlet-grass-17</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/h6tp8pec" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/h6tp8pec</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150214-h6tp8pec</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# <br/>Waiting for W&B process to finish, PID 9792<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150214-h6tp8pec\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150214-h6tp8pec\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">scarlet-grass-17</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/h6tp8pec" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/h6tp8pec</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">golden-wind-18</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3vp4abb2" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3vp4abb2</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150220-3vp4abb2</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 2360<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150220-3vp4abb2\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150220-3vp4abb2\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">golden-wind-18</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3vp4abb2" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3vp4abb2</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">usual-brook-19</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/135kvoes" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/135kvoes</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150226-135kvoes</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# <br/>Waiting for W&B process to finish, PID 6104<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=0.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150226-135kvoes\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150226-135kvoes\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">usual-brook-19</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/135kvoes" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/135kvoes</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">dulcet-cloud-20</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/hzwibzdb" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/hzwibzdb</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150232-hzwibzdb</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 8184<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150232-hzwibzdb\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150232-hzwibzdb\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">dulcet-cloud-20</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/hzwibzdb" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/hzwibzdb</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">magic-brook-21</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/ioc6g63p" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/ioc6g63p</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150238-ioc6g63p</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# <br/>Waiting for W&B process to finish, PID 3716<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150238-ioc6g63p\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150238-ioc6g63p\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">magic-brook-21</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/ioc6g63p" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/ioc6g63p</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">warm-mountain-22</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/w8myr9ip" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/w8myr9ip</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150244-w8myr9ip</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 4912<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150244-w8myr9ip\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_150244-w8myr9ip\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">warm-mountain-22</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/w8myr9ip" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/w8myr9ip</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">vivid-armadillo-23</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/2mh0hlb2" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/2mh0hlb2</a><br/>
# ...
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_153241-7tofok9m</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# <br/>Waiting for W&B process to finish, PID 1224<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_153241-7tofok9m\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_153241-7tofok9m\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">splendid-cosmos-313</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/7tofok9m" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/7tofok9m</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">grateful-snowball-314</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3t4qdju0" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3t4qdju0</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_153247-3t4qdju0</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# <br/>Waiting for W&B process to finish, PID 2564<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_153247-3t4qdju0\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_153247-3t4qdju0\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">grateful-snowball-314</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3t4qdju0" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3t4qdju0</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">noble-lake-315</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/4tgel3pp" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/4tgel3pp</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_153253-4tgel3pp</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# <br/>Waiting for W&B process to finish, PID 9316<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_153253-4tgel3pp\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_153253-4tgel3pp\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">noble-lake-315</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/4tgel3pp" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/4tgel3pp</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">usual-sun-316</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/1luqxjm4" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/1luqxjm4</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_153259-1luqxjm4</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# <br/>Waiting for W&B process to finish, PID 8980<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_153259-1luqxjm4\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_153259-1luqxjm4\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">usual-sun-316</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/1luqxjm4" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/1luqxjm4</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">azure-butterfly-317</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/jzuui0d4" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/jzuui0d4</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_153304-jzuui0d4</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# <br/>Waiting for W&B process to finish, PID 512<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_153304-jzuui0d4\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_153304-jzuui0d4\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">azure-butterfly-317</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/jzuui0d4" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/jzuui0d4</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">grateful-field-318</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/38x3kmxl" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/38x3kmxl</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_153309-38x3kmxl</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# <br/>Waiting for W&B process to finish, PID 15244<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_153309-38x3kmxl\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_153309-38x3kmxl\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">grateful-field-318</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/38x3kmxl" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/38x3kmxl</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">earthy-shadow-319</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3thuubjn" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3thuubjn</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_153315-3thuubjn</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# <br/>Waiting for W&B process to finish, PID 5216<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_153315-3thuubjn\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_153315-3thuubjn\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">earthy-shadow-319</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3thuubjn" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/3thuubjn</a><br/>
# wandb: wandb version 0.12.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">deft-fire-320</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/23yx6972" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/23yx6972</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_153320-23yx6972</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# <br/>Waiting for W&B process to finish, PID 6640<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_153320-23yx6972\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211006_153320-23yx6972\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">deft-fire-320</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes_Tend/runs/23yx6972" target="_blank">https://wandb.ai/rominacarmen/Expedientes_Tend/runs/23yx6972</a><br/>

# %% [markdown]
# ### Resultados de la optimización de hiperparámetros con Wandb
# Con un MAPE de **0,87%**, se obtienen las siguientes combinaciones de hiperparámetros:
#
# Run Time | damped_trend |initialization_method |seasonal |seasonal_periods | trend|
# :- | :- | :- | :- | :- | :-|
#  4s | false | heuristic | multiplicative | 51 |additive|
#  3s | false | heuristic | mul            | 51 |additive|
#  4s | false | heuristic | multiplicative | 51 |add     |
#  4s | false | heuristic | mul            | 51 |add     |
#  3s | false | estimated | multiplicative | 51 |additive|
#  4s | false | estimated | multiplicative | 51 | add    |
#  4s | false | estimated | mul            | 51 |additive|
#  3s | false | estimated | mul            | 51 |add     |

# %% [markdown]
# ## Prueba de optimización con expedientes agrupados por semana

# %%
params_w = {
    "trend": ["add", "mul", "additive", "multiplicative"],
    "damped_trend": [True, False],
    "seasonal": ["add", "mul", "additive", "multiplicative", None],
    "seasonal_periods": [4, 52],
    "initialization_method": [None, "estimated", "heuristic", "legacy-heuristic"]
}

parameter_grid_w = ParameterGrid(params_w)

len(parameter_grid_w)
# Out:
# 320

# %%
datos_train_w = df_train_w.Cant_Expte
datos_test_w = df_test_w.Cant_Expte

for parameter_w in parameter_grid_w:
    run = wandb.init(project = "Expedientes", reinit = True)
    run.config.update(parameter_w)
    
    model_SE_w = ExponentialSmoothing(datos_train_w, **parameter_w).fit()
    
    Pred_SE_w = model_SE_w.forecast(105)
    
    metrics_w = mean_absolute_percentage_error(datos_test_w, Pred_SE_w)
    metrics_w = {"MAPE": [metrics_w]}
    run.log(metrics_w)
    run.finish()
# Out:
# Finishing last run (ID:2yasuihz) before initializing another...
# <br/>Waiting for W&B process to finish, PID 14992<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182356-2yasuihz\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182356-2yasuihz\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">silver-voice-1630</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/2yasuihz" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/2yasuihz</a><br/>
# ...Successfully finished last run (ID:2yasuihz). Initializing new run:<br/><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">dutiful-firebrand-1631</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/2mesxi7s" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/2mesxi7s</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182416-2mesxi7s</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 4280<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182416-2mesxi7s\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182416-2mesxi7s\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">dutiful-firebrand-1631</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/2mesxi7s" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/2mesxi7s</a><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">drawn-yogurt-1632</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/32qaerh3" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/32qaerh3</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182426-32qaerh3</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 10468<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182426-32qaerh3\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182426-32qaerh3\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">drawn-yogurt-1632</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/32qaerh3" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/32qaerh3</a><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">hearty-frog-1633</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/12az93te" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/12az93te</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182432-12az93te</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 10760<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182432-12az93te\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182432-12az93te\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">hearty-frog-1633</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/12az93te" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/12az93te</a><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">worldly-sun-1634</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/2o9ybhoi" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/2o9ybhoi</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182438-2o9ybhoi</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 14092<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182438-2o9ybhoi\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182438-2o9ybhoi\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">worldly-sun-1634</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/2o9ybhoi" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/2o9ybhoi</a><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">floral-frost-1635</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/bt7lfg8z" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/bt7lfg8z</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182444-bt7lfg8z</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 8856<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182444-bt7lfg8z\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182444-bt7lfg8z\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">floral-frost-1635</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/bt7lfg8z" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/bt7lfg8z</a><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">honest-salad-1636</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/208vfgxo" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/208vfgxo</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182451-208vfgxo</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 12388<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182451-208vfgxo\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182451-208vfgxo\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">honest-salad-1636</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/208vfgxo" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/208vfgxo</a><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">deep-pyramid-1637</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/36beawzo" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/36beawzo</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182457-36beawzo</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 13584<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182457-36beawzo\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182457-36beawzo\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">deep-pyramid-1637</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/36beawzo" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/36beawzo</a><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">stilted-cloud-1638</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/1m9tl9t2" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/1m9tl9t2</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182503-1m9tl9t2</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 12428<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182503-1m9tl9t2\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182503-1m9tl9t2\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">stilted-cloud-1638</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/1m9tl9t2" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/1m9tl9t2</a><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">polished-disco-1639</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/1kd8juk6" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/1kd8juk6</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182509-1kd8juk6</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 564<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=0.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182509-1kd8juk6\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182509-1kd8juk6\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">polished-disco-1639</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/1kd8juk6" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/1kd8juk6</a><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">lively-breeze-1640</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/afn1iyqk" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/afn1iyqk</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182515-afn1iyqk</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 9204<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182515-afn1iyqk\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182515-afn1iyqk\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">lively-breeze-1640</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/afn1iyqk" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/afn1iyqk</a><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">major-microwave-1641</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/3lb9u5d1" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/3lb9u5d1</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182521-3lb9u5d1</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 9300<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182521-3lb9u5d1\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182521-3lb9u5d1\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">major-microwave-1641</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/3lb9u5d1" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/3lb9u5d1</a><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">sage-thunder-1642</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/7c0b9ij5" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/7c0b9ij5</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182528-7c0b9ij5</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 4248<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182528-7c0b9ij5\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182528-7c0b9ij5\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">sage-thunder-1642</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/7c0b9ij5" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/7c0b9ij5</a><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">youthful-firebrand-1643</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/20fectjd" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/20fectjd</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182534-20fectjd</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 2472<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182534-20fectjd\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182534-20fectjd\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">youthful-firebrand-1643</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/20fectjd" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/20fectjd</a><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">northern-voice-1644</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/6d9mse6u" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/6d9mse6u</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182540-6d9mse6u</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 7208<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182540-6d9mse6u\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182540-6d9mse6u\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">northern-voice-1644</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/6d9mse6u" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/6d9mse6u</a><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">clean-sea-1645</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/3izr83x7" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/3izr83x7</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182547-3izr83x7</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 14208<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182547-3izr83x7\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182547-3izr83x7\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">clean-sea-1645</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/3izr83x7" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/3izr83x7</a><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">whole-resonance-1646</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/3ueb924g" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/3ueb924g</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182552-3ueb924g</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 7908<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182552-3ueb924g\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182552-3ueb924g\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">whole-resonance-1646</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/3ueb924g" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/3ueb924g</a><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">major-dawn-1647</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/1thv1ph5" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/1thv1ph5</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182559-1thv1ph5</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 8456<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182559-1thv1ph5\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182559-1thv1ph5\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">major-dawn-1647</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/1thv1ph5" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/1thv1ph5</a><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">super-wave-1648</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/10171dnr" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/10171dnr</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182605-10171dnr</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 5916<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182605-10171dnr\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182605-10171dnr\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">super-wave-1648</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/10171dnr" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/10171dnr</a><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">warm-bush-1649</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/1zth9171" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/1zth9171</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182612-1zth9171</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 5856<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182612-1zth9171\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182612-1zth9171\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">warm-bush-1649</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/1zth9171" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/1zth9171</a><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">woven-river-1650</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/189uqra1" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/189uqra1</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182618-189uqra1</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 7524<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182618-189uqra1\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182618-189uqra1\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">woven-river-1650</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/189uqra1" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/189uqra1</a><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">vital-frost-1651</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/zyeqni7z" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/zyeqni7z</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182624-zyeqni7z</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 2820<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182624-zyeqni7z\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_182624-zyeqni7z\logs\debug-internal.log</code>
# ...
#                     <br/>Synced <strong style="color:#cdcd00">decent-forest-1943</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/26kdm3qn" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/26kdm3qn</a><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">peachy-darkness-1944</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/3uhslkbw" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/3uhslkbw</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_185936-3uhslkbw</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 8672<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_185936-3uhslkbw\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_185936-3uhslkbw\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">peachy-darkness-1944</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/3uhslkbw" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/3uhslkbw</a><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">scarlet-pyramid-1945</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/15jwu6fw" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/15jwu6fw</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_185942-15jwu6fw</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 4168<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_185942-15jwu6fw\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_185942-15jwu6fw\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">scarlet-pyramid-1945</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/15jwu6fw" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/15jwu6fw</a><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">deep-sound-1946</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/27yzrqlk" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/27yzrqlk</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_185948-27yzrqlk</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 13260<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_185948-27yzrqlk\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_185948-27yzrqlk\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">deep-sound-1946</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/27yzrqlk" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/27yzrqlk</a><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">generous-grass-1947</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/20h4c462" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/20h4c462</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_185955-20h4c462</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 6748<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_185955-20h4c462\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_185955-20h4c462\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">generous-grass-1947</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/20h4c462" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/20h4c462</a><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">lunar-blaze-1948</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/2axomhy7" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/2axomhy7</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_190001-2axomhy7</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 12736<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_190001-2axomhy7\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_190001-2axomhy7\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">lunar-blaze-1948</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/2axomhy7" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/2axomhy7</a><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">celestial-waterfall-1949</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/1qhuja1n" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/1qhuja1n</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_190007-1qhuja1n</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 11180<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=0.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_190007-1qhuja1n\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_190007-1qhuja1n\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">celestial-waterfall-1949</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/1qhuja1n" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/1qhuja1n</a><br/>
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">divine-sea-1950</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rominacarmen/Expedientes" target="_blank">https://wandb.ai/rominacarmen/Expedientes</a><br/>
#                 Run page: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/7pexoprd" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/7pexoprd</a><br/>
#                 Run data is saved locally in <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_190014-7pexoprd</code><br/><br/>
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 964<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_190014-7pexoprd\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\Usuario\Documents\Romina\03 Curso Data Science 2021\07 Trabajo Final\wandb\run-20211002_190014-7pexoprd\logs\debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">divine-sea-1950</strong>: <a href="https://wandb.ai/rominacarmen/Expedientes/runs/7pexoprd" target="_blank">https://wandb.ai/rominacarmen/Expedientes/runs/7pexoprd</a><br/>

# %% [markdown]
# ### Crear y entrenar el modelo de Suavizado Exponencial (SE) Optimizado
# - Se probará el modelo con una de las combinaciones encontradas

# %%
SE_O_w = ExponentialSmoothing(
   df_train_w['Cant_Expte'],
    trend='mul', 
    damped_trend= True, 
    #seasonal='mul',
    seasonal_periods=51, 
    initialization_method = 'legacy-heuristic').fit();
# Out:
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'

# %% [markdown]
# ### Predicciones usando SE Optimizado

# %%
Pred_SE_O_w = SE_O_w.forecast(105)
#Pred_SE_O_w= abs(Pred_SE_O_w)

# %% [markdown]
# ### Gráfico: Datos de trainning, test y las predicciones con SE Optimizado

# %%
fig, ax=plt.subplots()
df_train_w['Cant_Expte'].plot(ax=ax, label='Training', color="darkorange", alpha=1)
df_test_w['Cant_Expte'].plot(ax=ax, label='Test',color="firebrick", alpha=0.8)
#forecast_TESadd.plot(ax=ax, label='Pred SET-ADD',color="royalblue", alpha=1)
#forecast_TESmul.plot(ax=ax,label='Pred - SET-MUL',color="forestgreen", alpha=1)
Pred_SE_O_w.plot(ax=ax,label='Pred SE-O',color="royalblue", alpha=1)
plt.title("Datos de Trainning, Test y Predicciones con SE Optimizado", fontsize=22)
plt.xlabel("Años")
ax.legend();
#.iloc[2000:]

# %% [markdown]
# ___
# ## Evaluación del Error del Modelo SE Optimizado

# %% [markdown]
# ### MAE (Error Absoluto Medio)

# %%
MAE = mean_absolute_error(df_test_w['Cant_Expte'],Pred_SE_O_w)
print(f'MAE del modelo SE-O: {MAE:11.10}')
# Out:
# MAE del modelo SE-O: 691.7301784

# %% [markdown]
# ### MAPE (Error Porcentual Absoluto Medio)

# %%
MAPE = mean_absolute_percentage_error(df_test_w['Cant_Expte'],Pred_SE_O_w)
print(f'MAPE del modelo SE-O: {MAPE:11.10}')
# Out:
# MAPE del modelo SE-O: 0.1498275457

# %% [markdown]
# ### MSE (Error Cuadrático Medio)

# %%
MSE = mean_squared_error(df_test_w['Cant_Expte'],Pred_SE_O_w)
print(f'MSE del modelo SE-O: {MSE:11.10}')
# Out:
# MSE del modelo SE-O: 642920.1807

# %%
MSE_SE_O = MSE **0.5
MSE_SE_O
# Out:
# 801.8230357713231

# %% [markdown]
# ___
# ## Conclusiones Finales
# - Se concluye que hasta el momento **el modelo de Suavizado Exponencial Optimizado (SE-O) es el mejor modelo** para predecir los datos de nuestra serie de tiempo

# %% [markdown]
# ___
# ## Predicciones 2021
# ### Crear y entrenar el modelo SE Optimizado con todos los datos del dataset

# %%
SE_O_w_T = ExponentialSmoothing(
   df_Week['Cant_Expte'],
    trend='mul', 
    damped_trend= True, 
    #seasonal='mul',
    seasonal_periods=51, 
    initialization_method = 'heuristic').fit();
# Out:
# c:\users\usuario\appdata\local\programs\python\python38\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   warnings.warn('No frequency information was'

# %% [markdown]
# ## Predicciones para el modelo SE Optimizado con todos los datos del dataset

# %%
Pred_SE_O_w_T = SE_O_w_T.forecast(51)

# %% [markdown]
# ### Gráfico: Cantidad de Expedientes y Predicciones 2021 usando SE Optimizado

# %%
fig, ax=plt.subplots()
df_Week['Cant_Expte'].plot(ax=ax, label='Cantidad de Expedientes', color="darkorange", alpha=1)
Pred_SE_O_w_T.plot(ax=ax,label='Pred SE Optimizado',color="royalblue", alpha=1)
plt.title("Cantidad de Expedientes y Predicciones 2021 con SE Optimizado", fontsize=22)
plt.xlabel("Años")
ax.legend();
#.iloc[2000:]

# %% [markdown]
# ### Cálculo la cantidad de expedientes predecidos para el 2021 con el modelo SE-O

# %%
Pred_SE_O_w_T[:] = Pred_SE_O_w_T[:].astype(int)

# %%
Pred_SE_O_w_T.sum()
# Out:
# 249939

# %% [markdown]
# ___
# ## Predcciones Finales 2021
# ### Modelo Suavizado Exponencial con Hiperparámetros Optimizados (SE-O)
# - **Cantidad de Expedientes: 228.067**
# - **MAPE: 0,87%**

# %% [markdown]
# ___
# ## Recupero los datos que tengo disponibles hasta julio 2021, para compararlos con mi predicción

# %%
# Defino como índice la 1° columna y diciendo que es una fecha
#======================================================================
df_Week_2021 = pd.read_csv("df_Week_2021.csv", sep=';', index_col=0, parse_dates=True)
df_Week_2021.head()
# Out:
#                  Cant_Expte
# Fecha_Ini_Expte
# 2021-01-10             5063
# 2021-01-17             4987
# 2021-01-24             4196
# 2021-01-31             4123
# 2021-02-07             4267

# %% [markdown]
# ### Gráfico: Comparación de predicciones 2021 con datos del 2021 disponibles hasta julio

# %%
fig, ax=plt.subplots()
df_Week['Cant_Expte'].plot(ax=ax, label='Expedientes', color="darkorange", alpha=1)
df_Week_2021['Cant_Expte'].plot(ax=ax, label='Expedientes Ene-Ago 2021', color="firebrick", alpha=0.8)
Pred_SE_O_w_T.plot(ax=ax,label='Pred SE-O',color="royalblue", alpha=1)
plt.title("Predicciones 2021 y datos de Enero a 4 de Agosto 2021", fontsize=22)
plt.xlabel("Años")
ax.legend();
#.iloc[200:]

# %% [markdown]
# ### Cantidad de Expedientes inicados en 2021 hasta julio

# %%
df_Week_2021['Cant_Expte'].sum()
# Out:
# 151813
